# %%
# Cargamos el acceso a  nuestro drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Nos movemos a la ruta y verificamos
# %cd '/content/drive/My Drive/Colab Notebooks'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks
#  curso_pandas   db  'Primeros pasos.ipynb'   Untitled0.ipynb

# %%
# Creamos un directorio
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/db
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/db’: File exists

# %%
dir_pandas = '/content/drive/My\ Drive/Colab\ Notebooks/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My\\ Drive/Colab\\ Notebooks/db/test.csv'

# %%
import pandas as pd
pd.__version__
import numpy as np

# %%
dict_data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas='/content/drive/My Drive/Colab Notebooks/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/test.csv'

# %%
# Escribir un archivo
df.to_csv(dir_pandas, index=False)

# %%
#Leer un archivo

# %%
df_reaad = pd.read_csv('/content/drive/My Drive/Colab Notebooks/db/text.csv')
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Guardando pero con un separador
df.to_csv(dir_pandas, sep='|', index=False)

# %%
# Leyendo los datos tomando en cuenta el separador
df_reaad = pd.read_csv('/content/drive/My Drive/Colab Notebooks/db/text.csv', sep="|")
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas='/content/drive/My Drive/Colab Notebooks/db/{}'
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/{}'

# %%
# Guardamos en excel
# Evitamos crear otra columna index=False
df.to_excel(dir_pandas.format('test.xlsx'), index=False, sheet_name='hoja_uno')

# %%
# Leer un Excel
pd.read_excel(dir_pandas.format('test.xlsx'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Guardando un JSON
df.to_json(dir_pandas.format('test.json'))

# %%
# Leer JSON
pd.read_json(dir_pandas.format('test.json'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Guardando en binario con el pickle (dataframe de tamaño mediano)
df.to_pickle(dir_pandas.format('test.pkl'))

# %%
# Leer pickle
pd.read_pickle(dir_pandas.format('test.pkl'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Guardando parquet
df.to_parquet(dir_pandas.format('test.parquet'))

# %%
# Leer parquet
pd.read_parquet(dir_pandas.format('test.parquet'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Guardando hdf(hadoop)
df.to_hdf(dir_pandas.format('test.hdf'), key='data', format='table')

# %%
# Leer hdf
pd.read_hdf(dir_pandas.format('test.hdf'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9
